# %% [markdown]
# <h1 style="text-align: center;">  Online Likelihood-Ratio Estimation (OLRE) </h1>

# %%
from Models import *
from Models.Offline_LRE import *
import matplotlib.pyplot as plt
from Experiments import *
from Evaluation import *
import numpy as np
import scipy
from scipy.special import logsumexp

# %% [markdown]
# The goal of this jupyter notebook is to illustrate how to use OLRE

# %% [markdown]
# ## <center>Experiment I</center>

# %% [markdown]
# ### Data Visualization

# %%
data_ref_validation=np.random.uniform(-np.sqrt(3),np.sqrt(3),size=10000)
data_test_validation=np.random.laplace(loc=0,scale=np.sqrt(0.5),size=10000)

# %%
#### Real likelihood-ratio
def r_uniform_laplace(x,alpha):
    log_r_alpha=alpha*scipy.stats.laplace.pdf(x,loc=0,scale=np.sqrt(0.5))+(1-alpha)*scipy.stats.uniform.pdf(x,loc=-np.sqrt(3),scale=2*np.sqrt(3))
    log_r_alpha[log_r_alpha<=0]=1e-16
    log_r_alpha=-1*np.log(log_r_alpha)
    log_r_alpha+=scipy.stats.laplace.logpdf(x,loc=0,scale=np.sqrt(0.5))
    return np.exp(log_r_alpha)

# %%
##### Data distributions
plt.hist(data_ref_validation,alpha=0.5,color="#f44174",label=r'$x \ \sim p$')
plt.hist(data_test_validation,alpha=0.5,color="#4286f4",label=r"$x' \sim q$")
plt.tick_params(axis="x", labelsize=10) 
plt.tick_params(axis="y", labelsize=10) 
plt.legend(fontsize=15)

# %%
alpha=0.1
x=np.arange(-1.0,1.0,1/100)
y= r_uniform_laplace(x,alpha=alpha)
plt.plot(x,y)
plt.tick_params(axis="x", labelsize=10) 
plt.tick_params(axis="y", labelsize=10) 
plt.title(r"Relative Likelihood-Ratio $\alpha=$"+str(alpha))
# Out:
# Text(0.5, 1.0, 'Relative Likelihood-Ratio $\\alpha=$0.1')

# %% [markdown]
# ### Fitting OLRE

# %%
data_ref=np.random.uniform(-np.sqrt(3),np.sqrt(3),size=5000)
data_test=np.random.laplace(loc=0,scale=np.sqrt(0.5),size=5000)
########### OLRE
warming_period=100 ### Warming period 
alpha=0.1 ### regularized parameter 
smoothness=1.0 ### smoothness parameter(should be between 0.5 and 1 to guarantee convergence)
dictionary_OLRE,list_thetas_OLRE,Kernel_OLRE=OLRE(data_ref,data_test,warming_period,smoothness,alpha=alpha)

# %%
x=np.arange(np.mean(data_ref)-1.5*np.std(data_ref),np.mean(data_ref)+1.5*np.std(data_ref),1/100)
y= r_uniform_laplace(x,alpha)
y_estimate_OLRE=r_estimate(x,Kernel_OLRE,dictionary_OLRE,list_thetas_OLRE[len(list_thetas_OLRE)-1])

# %%
##### Real Likelihood-ratio
alpha=0.1
plt.plot(x,y,label="real relative LR")
plt.plot(x,y_estimate_OLRE,label="OLRE Estimate")
plt.tick_params(axis="x", labelsize=10) 
plt.tick_params(axis="y", labelsize=10) 
plt.legend()
plt.title(r"Relative Likelihood-Ratio $\alpha=$"+str(alpha))
# Out:
# Text(0.5, 1.0, 'Relative Likelihood-Ratio $\\alpha=$0.1')

# %% [markdown]
# ### Convergence in L_2

# %%
########## Convergence 
data_ref_validation=np.random.uniform(-np.sqrt(3),np.sqrt(3),size=10000)
data_test_validation=np.random.laplace(loc=0,scale=np.sqrt(0.5),size=10000)   
reduced_list_thetas_OLRE=[list_thetas_OLRE[i] for i in range(0,len(list_thetas_OLRE),100)]
errors_PEARSON_OLRE,L2_distance_OLRE=error_plot(data_ref_validation,data_test_validation,dictionary_OLRE,reduced_list_thetas_OLRE,Kernel_OLRE,
                                                 real_likelihood=lambda x: r_uniform_laplace(x,alpha=alpha),alpha=alpha)

# %%
index=np.arange(100+warming_period,len(list_thetas_OLRE)+100+warming_period,100)
plt.title("Convergence in L2 Distance")
plt.plot(index,np.log(L2_distance_OLRE),label=rf'OLRE $\alpha={alpha}, \beta={smoothness}$')
plt.ylabel(r'$\log(L_2(f_t,r_{\alpha}))$',fontsize=20)
plt.xlabel(r'$\#$ of iterations',fontsize=20)
plt.legend(fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# %% [markdown]
# ## <center>Experiment III</center>

# %% [markdown]
# ### Data Visualization

# %%
T=10000
data_ref_validation,data_test_validation=data_experiment_3(N=T)

# %%
#### Real likelihood-ratio
real_likelihood=lambda x: r_normal_mixture(x,alpha=alpha)

# %%
##### Data distributions
plt.scatter(data_ref_validation[:,0],data_ref_validation[:,1],alpha=0.5,color="#4286f4",label=r'$x \ \sim p$')
plt.scatter(data_test_validation[:,0],data_test_validation[:,1],alpha=0.5,color="#f44174",label=r"$x' \sim q$")
plt.tick_params(axis="x", labelsize=10) 
plt.tick_params(axis="y", labelsize=10) 
plt.legend(fontsize=15)

# %%
alpha=0.1
x=np.arange(-10.0,10.0,1/10)
y=np.arange(-10.0,10.0,1/10)
X, Y = np.meshgrid(x, y)  # Cartesian grid
cartesian_product = np.column_stack([X.ravel(), Y.ravel()])  # Reshape to (N,2) form
Z=real_likelihood(cartesian_product)
Z = Z.reshape(X.shape)  # Ensure Z matches X, Y dimensions

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y,Z, cmap='viridis')
plt.tick_params(axis="x", labelsize=10) 
plt.tick_params(axis="y", labelsize=10) 
plt.title(r"Relative Likelihood-Ratio $\alpha=$"+str(alpha))
plt.show()

# %% [markdown]
# ### Fitting OLRE

# %%
T=5000
data_ref,data_test=data_experiment_3(N=T)
########### OLRE
warming_period=100 ### Warming period 
alpha=0.1 ### regularized parameter 
smoothness=0.5 ### smoothness parameter(should be between 0.5 and 1 to guarantee convergence)
dictionary_OLRE,list_thetas_OLRE,Kernel_OLRE=OLRE(data_ref,data_test,warming_period,smoothness,alpha=alpha)

# %%
alpha=0.1
x=np.arange(-10.0,10.0,1/10)
y=np.arange(-10.0,10.0,1/10)
X, Y = np.meshgrid(x, y)  # Cartesian grid
cartesian_product = np.column_stack([X.ravel(), Y.ravel()])  # Reshape to (N,2) form
Z=real_likelihood(cartesian_product)
Z = Z.reshape(X.shape)  # Ensure Z matches X, Y dimensions
Z_estimate_OLRE=r_estimate(cartesian_product,Kernel_OLRE,dictionary_OLRE,list_thetas_OLRE[len(list_thetas_OLRE)-1])
Z_estimate_OLRE = Z_estimate_OLRE.reshape(X.shape)  # Ensure Z matches X, Y dimensions

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create figure
fig = plt.figure(figsize=(12, 6))

# Create two 3D subplots
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax2 = fig.add_subplot(1, 2, 2, projection='3d')

# First surface plot
ax1.plot_surface(X, Y, Z, cmap='viridis')
ax1.set_title(r"Relative Likelihood-Ratio $\alpha=$"+str(alpha))

# Second surface plot
ax2.plot_surface(X, Y, Z_estimate_OLRE, cmap='viridis')
ax2.set_title(r"Estimated Likelihood-Ratio $\alpha=$"+str(alpha))

# Show plot
plt.show()

# %% [markdown]
# ### Convergence in L_2

# %%
########## Convergence 
T=10000
data_ref_validation,data_test_validation=data_experiment_3(N=T)
reduced_list_thetas_OLRE=[list_thetas_OLRE[i] for i in range(0,len(list_thetas_OLRE),100)]
errors_PEARSON_OLRE,L2_distance_OLRE=error_plot(data_ref_validation,data_test_validation,dictionary_OLRE,reduced_list_thetas_OLRE,Kernel_OLRE,
                                                 real_likelihood,alpha=alpha)

# %%
index=np.arange(100+warming_period,len(list_thetas_OLRE)+100+warming_period,100)
plt.title("Convergence in L2 Distance")
plt.plot(index,np.log(L2_distance_OLRE),label=rf'OLRE $\alpha={alpha}, \beta={smoothness}$')
plt.ylabel(r'$\log(L_2(f_t,r_{\alpha}))$',fontsize=20)
plt.xlabel(r'$\#$ of iterations',fontsize=20)
plt.legend(fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
